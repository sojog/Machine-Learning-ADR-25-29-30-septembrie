# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([1], [2])

# %%
plt.scatter([1, 5], [2, 9])

# %%
plt.scatter([1, 5, 3,], [2, 9, 5])

# %%
plt.scatter([1, 5, 3,], [2, 1, 5])

# %%
plt.plot([1, 5, 3,], [2, 1, 5])

# %%
import numpy as np

# %%
x = np.random.randint(0, 10, 4)
y = np.random.randint(0, 10, 4)
plt.scatter(x, y)
plt.plot(x, y)
