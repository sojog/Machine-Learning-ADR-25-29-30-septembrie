# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
rezultat = make_regression(1000, 1, noise=30)
rezultat
# Out:
# (array([[-2.45782089e-01],
#         [ 4.07836046e-01],
#         [-1.36557153e+00],
#         [ 1.41592878e+00],
#         [ 7.59287772e-01],
#         [-1.09276731e+00],
#         [-8.76306500e-01],
#         [ 8.18240325e-01],
#         [-1.52246272e+00],
#         [ 1.18980016e+00],
#         [ 4.63040679e-01],
#         [ 6.79406433e-01],
#         [-1.38857471e-01],
#         [-8.23547660e-01],
#         [ 1.22547519e+00],
#         [-1.14421675e+00],
#         [ 2.22399228e+00],
#         [ 7.96470718e-01],
#         [ 9.79263366e-01],
#         [-1.55211883e+00],
#         [ 2.04944485e-01],
#         [-1.04328461e+00],
#         [-4.42137491e-01],
#         [-8.03421220e-01],
#         [ 7.73704230e-01],
#         [-1.18497234e-01],
#         [-8.00929319e-01],
#         [ 2.25953472e+00],
#         [ 1.49348006e-01],
#         [ 5.09038186e-01],
#         [-1.05401443e+00],
#         [ 1.12947360e+00],
#         [-1.09998350e+00],
#         [-7.02027371e-01],
# ...

# %%
plt.scatter(rezultat[0], rezultat[1])
